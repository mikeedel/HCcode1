# %% [markdown]
# # Analisis de compras de Ulabox
# ### Obtención de estadisticas descriptivas
#
# Cargar los archivos usando panda y utilizar seaborn para obtener visualizaciones

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('ulabox.csv')
df.head()
# Out:
#    customer  order  total_items  discount%  weekday  hour  Food%  Fresh%  \
# 0         0      0           45      23.03        4    13   9.46   87.06
# 1         0      1           38       1.22        5    13  15.87   75.80
# 2         0      2           51      18.08        4    13  16.88   56.75
# 3         1      3           57      16.51        1    12  28.81   35.99
# 4         1      4           53      18.31        2    11  24.13   60.38
#
#    Drinks%  Home%  Beauty%  Health%  Baby%  Pets%
# 0     3.48   0.00     0.00     0.00    0.0    0.0
# 1     6.22   2.12     0.00     0.00    0.0    0.0
# 2     3.37  16.48     6.53     0.00    0.0    0.0
# 3    11.78   4.62     2.87    15.92    0.0    0.0
# 4     7.78   7.72     0.00     0.00    0.0    0.0

# %% [markdown]
# Revisar los tipos de datos dentro de la base de datos

# %%
df.dtypes
# Out:
# customer         int64
# order            int64
# total_items      int64
# discount%      float64
# weekday          int64
# hour             int64
# Food%          float64
# Fresh%         float64
# Drinks%        float64
# Home%          float64
# Beauty%        float64
# Health%        float64
# Baby%          float64
# Pets%          float64
# dtype: object

# %% [markdown]
# Obtener información reelevante sobre los datos, como media, moda y mediana.

# %%
df.describe()
# Out:
#            customer         order   total_items     discount%       weekday  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    5012.483367  14999.500000     31.739933      8.455495      3.642367
# std     2888.646245   8660.398374     20.576579     14.199350      2.122031
# min        0.000000      0.000000      1.000000    -65.150000      1.000000
# 25%     2541.750000   7499.750000     18.000000      1.177500      2.000000
# 50%     5043.000000  14999.500000     29.000000      4.160000      3.000000
# 75%     7483.000000  22499.250000     41.000000      9.990000      5.000000
# max    10238.000000  29999.000000    298.000000    100.000000      7.000000
#
#                hour         Food%        Fresh%       Drinks%         Home%  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      15.034667     23.560406     20.227279     23.349235     13.539575
# ...

# %%
print("Longitud de los datos: ", len(df))
# Out:
# Longitud de los datos:  30000

# %%
df[['Food%', 'Fresh%', 'Drinks%', 'Home%', 'Beauty%', 'Health%', 'Baby%', 'Pets%']].describe()
# Out:
#               Food%        Fresh%       Drinks%         Home%       Beauty%  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      23.560406     20.227279     23.349235     13.539575      5.892949
# std       21.719824     23.661767     22.523335     17.850282     13.996518
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        7.220000      0.000000      6.710000      0.000000      0.000000
# 50%       19.650000     10.930000     17.890000      7.210000      0.000000
# 75%       33.260000     35.790000     33.162500     20.002500      6.512500
# max      100.000000    100.000000    100.000000    100.000000    100.000000
#
#             Health%         Baby%         Pets%
# count  30000.000000  30000.000000  30000.000000
# mean       1.132959     11.096145      1.043087
# std        5.307620     24.740364      6.195390
# min        0.000000      0.000000      0.000000
# ...

# %%
df['weekday'].mode()
# Out:
# 0    1
# Name: weekday, dtype: int64

# %%
df['hour'].mode()
# df['hour'].mean()
# Out:
# 0    22
# Name: hour, dtype: int64

# %%
df['discount%'].max()
# Out:
# 100.0

# %%
df['customer'].mode()
# Out:
# 0    6560
# Name: customer, dtype: int64

# %% [markdown]
# ### Mapas de calor y boxplots

# %%
sns.displot(x="customer", y = "total_items", data=df)

# %%
sns.displot(x="order", y = "total_items", data=df)

# %%
sns.displot(x="order", data=df)

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('ulabox.csv')
df2 = pd.DataFrame(df)
#df2["total_items"].drop(0,axis=0)
eleazar = df2["Home%"]>0
otra = df2[eleazar]
sns.displot(x="Home%", data=otra)

# %%
sns.displot(x="discount%", data=df)

# %%
sns.displot(x="weekday", data=df)

# %%
sns.displot(x="hour", data=df)

# %%
sns.displot(x="Food%", data=df)

# %%
sns.displot(x="Fresh%", data=df)

# %%
sns.displot(x="Drinks%", data=df)

# %%
sns.displot(x="Home%", data=df)

# %%
sns.displot(x="Beauty%", data=df)

# %%
df['total_items_cat'] = pd.cut(df.total_items, [0, 20, 100, 300], labels = ['Compra pequeña', 'Compra mediana', 'Compra grande'])
df.head()
# Out:
#    customer  order  total_items  discount%  weekday  hour  Food%  Fresh%  \
# 0         0      0           45      23.03        4    13   9.46   87.06
# 1         0      1           38       1.22        5    13  15.87   75.80
# 2         0      2           51      18.08        4    13  16.88   56.75
# 3         1      3           57      16.51        1    12  28.81   35.99
# 4         1      4           53      18.31        2    11  24.13   60.38
#
#    Drinks%  Home%  Beauty%  Health%  Baby%  Pets% total_items_cat
# 0     3.48   0.00     0.00     0.00    0.0    0.0  Compra mediana
# 1     6.22   2.12     0.00     0.00    0.0    0.0  Compra mediana
# 2     3.37  16.48     6.53     0.00    0.0    0.0  Compra mediana
# 3    11.78   4.62     2.87    15.92    0.0    0.0  Compra mediana
# 4     7.78   7.72     0.00     0.00    0.0    0.0  Compra mediana

# %%
sns.displot(data = df, x = 'total_items_cat')
