# %%
import numpy as np; np.random.seed(42)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("ulabox.csv")

sns.boxplot(x="variable", y="value", data=pd.melt(df[["Food%","Fresh%","Drinks%","Home%","Beauty%","Health%","Baby%","Pets%"]]))

plt.show()
